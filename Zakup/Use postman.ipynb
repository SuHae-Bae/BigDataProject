# %%
import json

# %%
import requests

url = "https://new.land.naver.com/api/articles"

querystring = {"cortarNo":"1168010400",
               "order":"rank",
               "realEstateType":"APT%3AOPST%3AABYG%3AOBYG%3AGM%3AOR%3AVL%3ADDDGG%3AJWJT%3ASGJT%3AHOJT",
               "tradeType":"",
               "tag":"%3A%3A%3A%3A%3A%3A%3ASMALLSPCRENT%3AONEROOM",
               "rentPriceMin":"0",
               "rentPriceMax":"900000000",
               "priceMin":"0",
               "priceMax":"900000000",
               "areaMin":"0",
               "areaMax":"900000000",
               "oldBuildYears":"",
               "recentlyBuildYears":"",
               "minHouseHoldCount":"",
               "maxHouseHoldCount":"",
               "showArticle":"false",
               "sameAddressGroup":"false",
               "minMaintenanceCost":"",
               "maxMaintenanceCost":"",
               "priceType":"RETAIL",
               "directions":"",
               "page":"2",
               "articleState":""}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.220 Whale/1.3.51.7 Safari/537.36',
    'Referer': 'https://new.land.naver.com/'
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"isMoreData":true,"articleList":[{"articleNo":"1929631650","articleName":"청담자이","articleStatus":"R0","realEstateTypeCode":"APT","realEstateTypeName":"아파트","articleRealEstateTypeCode":"A01","tradeTypeCode":"A1","tradeTypeName":"매매","verificationTypeCode":"OWNER","floorInfo":"14/32","priceChangeState":"SAME","isPriceModification":false,"dealOrWarrantPrc":"17억","areaName":"70B","area1":70,"area2":49,"direction":"","articleConfirmYmd":"20191204","representativeImgUrl":"/20191204_190/land_naver_1575443824083GJhWI_JPEG/1546855416757189.jpg","representativeImgTypeCode":"10","representativeImgThumb":"f130_98","siteImageCount":0,"articleFeatureDesc":"직접매물,로열층 인기타입,세안고,추천매물","tagList":["10년이내","역세권","방두개","화장실한개"],"buildingName":"101동","sameAddrCnt":14,"sameAddrDirectCnt":0,"sameAddrMaxPrc":"17억","sameAddrMinPrc":"16억 8,000","cpid":"NEONET","cpName":"부동산뱅크","cpPcArticleUrl":"http://www.neonet.co.kr/rd/rd.php?UID=1929631650","cpPcArticleBridgeUrl":"","cpPcArticleLinkUseAtArticleTitleYn":false,
# ...

# %%
response.text
# Out:
# '{"code":"success","more":false,"TIME":false,"z":9,"page":1,"body":[]}'

# %%
data = json.loads(response.text)

# %%
data
# Out:
# {'isMoreData': True,
#  'articleList': [{'articleNo': '1929315691',
#    'articleName': '아노블리81',
#    'articleStatus': 'R0',
#    'realEstateTypeCode': 'OPST',
#    'realEstateTypeName': '오피스텔',
#    'articleRealEstateTypeCode': 'A02',
#    'tradeTypeCode': 'B1',
#    'tradeTypeName': '전세',
#    'verificationTypeCode': 'SITE',
#    'floorInfo': '8/16',
#    'priceChangeState': 'SAME',
#    'isPriceModification': False,
#    'dealOrWarrantPrc': '8억 5,000',
#    'areaName': '110C',
#    'area1': 110,
#    'area2': 56,
#    'direction': '남향',
#    'articleConfirmYmd': '20191203',
#    'representativeImgUrl': '/20191203_182/land_naver_1575373022719YaHM3_JPEG/PM-1.P-eq/61f1e429815e8b8834c23635d18933ec.JPG',
#    'representativeImgTypeCode': 'P360',
#    'representativeImgThumb': 'preview1920',
#    'siteImageCount': 14,
#    'articleFeatureDesc': '단독테라스가 있는 고급 오피스텔입니다.',
#    'tagList': ['2년이내', '융자금없는', '테라스', '역세권'],
#    'buildingName': '1동',
#    'sameAddrCnt': 2,
# ...

# %%
items = data['articleList']

# %%
items[0]
# Out:
# {'articleNo': '1929315691',
#  'articleName': '아노블리81',
#  'articleStatus': 'R0',
#  'realEstateTypeCode': 'OPST',
#  'realEstateTypeName': '오피스텔',
#  'articleRealEstateTypeCode': 'A02',
#  'tradeTypeCode': 'B1',
#  'tradeTypeName': '전세',
#  'verificationTypeCode': 'SITE',
#  'floorInfo': '8/16',
#  'priceChangeState': 'SAME',
#  'isPriceModification': False,
#  'dealOrWarrantPrc': '8억 5,000',
#  'areaName': '110C',
#  'area1': 110,
#  'area2': 56,
#  'direction': '남향',
#  'articleConfirmYmd': '20191203',
#  'representativeImgUrl': '/20191203_182/land_naver_1575373022719YaHM3_JPEG/PM-1.P-eq/61f1e429815e8b8834c23635d18933ec.JPG',
#  'representativeImgTypeCode': 'P360',
#  'representativeImgThumb': 'preview1920',
#  'siteImageCount': 14,
#  'articleFeatureDesc': '단독테라스가 있는 고급 오피스텔입니다.',
#  'tagList': ['2년이내', '융자금없는', '테라스', '역세권'],
#  'buildingName': '1동',
#  'sameAddrCnt': 2,
#  'sameAddrDirectCnt': 0,
#  'sameAddrMaxPrc': '9억 5,000',
#  'sameAddrMinPrc': '8억 5,000',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(items)

# %%
df.head(10)
# Out:
#     articleNo  articleName articleStatus realEstateTypeCode  \
# 0  1929315691       아노블리81            R0               OPST
# 1  1929401339       중소형사무실            R0                SMS
# 2  1929399594  중소형사무실 유현빌딩            R0                SMS
# 3  1929263821       중소형사무실            R0                SMS
# 4  1929105860         일반원룸            R0                 OR
# 5  1929100647           빌라            R0                 VL
# 6  1929089727       아노블리81            R0               OPST
# 7  1929088999       아노블리81            R0               OPST
# 8  1929085776           빌라            R0                 VL
# 9  1929082242       중소형사무실            R0                SMS
#
#   realEstateTypeName articleRealEstateTypeCode tradeTypeCode tradeTypeName  \
# 0               오피스텔                       A02            B1            전세
# 1                사무실                       D01            B2            월세
# 2                사무실                       D01            B2            월세
# ...
