# %%
import urllib.request
from bs4 import BeautifulSoup
from time import sleep

user_agent = 'Mozilla/5.0'
headers = {'User-Agent': user_agent}
target_url = 'https://new.land.naver.com/complexes?ms=37.5771187,126.9298968,12&a=APT:JGC:ABYG&e=RETAIL'

request = urllib.request.Request( url=target_url, headers=headers)
req = urllib.request.urlopen(request)
data = req.read()
soup = BeautifulSoup(data, 'html.parser')




# url = 'https://new.land.naver.com/rooms?ms=37.576192,126.921263,11&a=APT:OPST:ABYG:OBYG:GM:OR:VL:DDDGG:JWJT:SGJT:HOJT&e=RETAIL&aa=SMALLSPCRENT'

# req = urllib.request.urlopen(url)
# data = req.read()
# soup = BeautifulSoup(data, 'html.parser')
# sleep(2)

paytype = soup.select('div')

for item in paytype:
    print(item.text)
# Out:
# 본문 바로가기매물 필터 바로가기매물 목록 바로가기지도 바로가기
# 부동산검색 영역통합검색매물 이전버전 보기주택유형 선택아파트오피스텔빌라주택원룸투룸상가업무공장토지분양MY관심경매커뮤니티뉴스테마부동산부동산관리센터본문 영역필터영역원룸,투룸 필터 원룸 투룸오피스텔만 보기거래방식거래방식전체전세월세단기임대중복선택이 가능합니다.전체가격대매매가/전세가/보증금02003005001천2천3천4천5천6천7천8천9천1억2억3억3억~최소 금액최대 금액월세1020304050607080901백2백2백~최소 금액최대 금액최소금액을 선택하세요.조건삭제전체관리비관리비전체최소값을 선택하세요.최대값을 선택하세요. 5 10 15 20 25 30조건삭제전체기타옵션기타풀옵션옥탑복층분리형큰길가주차가능신축중복선택이 가능합니다.전체랭킹순매물 정보의 진정성을 점수화하며 높은 순으로 정렬매물 정보의 진정성은 네이버 부동산의 내부 정책에 따라 산정됩니다.최신순가격순면적순동일매물 묶기해당되는 매물이 없습니다.지역 선택시/도시/군/구읍/면/동지역 선택 팝업시/도읍/면/동읍/면/동가나다순세대수순최근입주순평당가순선택시 우측 패널에 단지정보가 표시됩니다.선택시 좌측 패널에 매물목록이 표시됩니다.선택시 좌측 패널에 공인중개사 정보 및 매물목록이 표시됩니다.선택된 편의시설이 지도에 표시됩니다.
# ...

# %%
#클릭을 해서 알아봐야 하기 때문에 webdriver와 selenium을 사용해야할것 같음

# %%
# 네이버는 그냥 크롤링하면 봇으로 인식함. 별도의 작업 필요
